# %%
# 数据预处理
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
from utils.label_index_convert import LabelIndexConvert
from dataset import Dog_dataset

current_path = os.getcwd()

label_index_convert = LabelIndexConvert(current_path)

train_data_set = Dog_dataset(root_path=current_path,
                             transform=None,
                             mode='train',
                             label_index_convert=label_index_convert)

for step,(x,y) in enumerate(train_data_set):
    print(x,y)
    print(x.shape)
    plt.imshow(x.permute(1,2,0))
    break
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# boston_bull
# boston_bull
# tensor([[[ 0.2000,  0.2941,  0.2941,  ...,  0.6392,  0.4667,  0.4745],
#          [ 0.2706,  0.1765,  0.2784,  ...,  0.8118,  0.6706,  0.5294],
#          [-0.0588, -0.0353,  0.5059,  ...,  0.7412,  0.7647,  0.6784],
#          ...,
#          [ 0.4667,  0.4431,  0.4745,  ...,  0.3961,  0.7647,  0.7176],
#          [ 0.4667,  0.4510,  0.4902,  ...,  0.2314,  0.6235,  0.6471],
#          [ 0.4353,  0.4588,  0.4902,  ...,  0.0667,  0.4353,  0.5216]],
#
#         [[-0.2784, -0.1373, -0.0745,  ...,  0.4510,  0.2314,  0.2235],
#          [-0.1451, -0.1922, -0.0431,  ...,  0.5922,  0.4275,  0.2784],
#          [-0.3882, -0.3490,  0.2235,  ...,  0.4824,  0.5059,  0.4118],
#          ...,
#          [-0.0588, -0.0824, -0.0353,  ..., -0.0275,  0.3490,  0.3020],
#          [-0.0588, -0.0745, -0.0275,  ..., -0.2471,  0.1922,  0.2314],
#          [-0.0902, -0.0667, -0.0275,  ..., -0.4588,  0.0039,  0.1137]],
#
#         [[-0.6549, -0.5373, -0.5059,  ..., -0.4510, -0.4588, -0.3647],
#          [-0.4667, -0.5373, -0.4196,  ..., -0.2157, -0.3098, -0.4039],
#          [-0.6549, -0.6314, -0.0824,  ..., -0.1922, -0.2863, -0.3882],
#          ...,
#          [-0.4745, -0.4980, -0.4431,  ..., -0.3725, -0.0353, -0.0745],
#          [-0.4745, -0.4902, -0.4353,  ..., -0.5373, -0.2078, -0.1843],
#          [-0.5059, -0.4824, -0.4353,  ..., -0.7098, -0.4196, -0.3412]]]) tensor(19)
# torch.Size([3, 224, 224])
